# %% [markdown]
# # Análise de Métodos de Sorteamento

# %% [markdown]
# A seguir seguem uma anális de gráficos para três diferentes tipos de sorteamento, sendo eles: SelectionSort, InsertionSort, BubbleSort. Antes da análise geral dos dados coletados, há um gráfico feito para cada PC que rodou o código de sorteamento. No final, há uma análise sobre o resultado obtido.

# %%
#Import de bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import mysql.connector as sql

# %%
#Conexão com o banco e Leitura de dados

db_connection = sql.connect(host='mysql.LCStuber.net', database='T1_CIC203', user='login', password='senha', auth_plugin='mysql_native_password')
db_cursor = db_connection.cursor()
db_cursor.execute('SELECT * FROM resultados order by id desc')

table_rows = db_cursor.fetchall()

db_connection.close()
db_cursor.close()

dados = pd.DataFrame(table_rows, columns=["ID", "tamanho", "tempo", "pc", "tipo"])
dados['tamanho'] = dados['tamanho'].astype('int')
dados.head(10)
# Out:
#      ID  tamanho    tempo             pc           tipo
# 0  2957   320000   141866  LAPTOP-NEWTON     bubbleSort
# 1  2956  2560000  1811347        Othavio  selectionSort
# 2  2955  2560000  1808573        Othavio  insertionSort
# 3  2954  2560000  8455409        Othavio     bubbleSort
# 4  2953  1280000   432986        Othavio  selectionSort
# 5  2952  1280000   460147        Othavio  insertionSort
# 6  2951  1280000  2095327        Othavio     bubbleSort
# 7  2950  1280000   434283        Othavio  selectionSort
# 8  2949  1280000   457732        Othavio  insertionSort
# 9  2948  1280000  2092452        Othavio     bubbleSort

# %%
#Dados gerais
tipos = ["selectionSort","insertionSort","bubbleSort"]
quantidade = [40000,80000,160000,320000,640000,1280000,2560000]

# %%
#Dados DESKTOP-LSTUBER

media_lstuber_selection = []
media_lstuber_insertion = []
media_lstuber_bubble = []
dados_lstuber = dados.loc[dados["pc"] == "DESKTOP-LSTUBER", :]

for tipo in tipos:
    for qntd in quantidade:
        dados_selection = dados_lstuber.loc[dados_lstuber["tipo"] == tipo, :]
        dados_selection = dados_selection.loc[dados_selection["tamanho"] == qntd, :]
        if (tipo=="selectionSort"):
            media_lstuber_selection.append(dados_selection["tempo"].mean())
        elif tipo == "insertionSort":
            media_lstuber_insertion.append(dados_selection["tempo"].mean())
        else:
            media_lstuber_bubble.append(dados_selection["tempo"].mean())

plt.plot(quantidade,media_lstuber_selection, label="SelectionSort")
plt.plot(quantidade,media_lstuber_insertion, label="InsertionSort")
plt.plot(quantidade,media_lstuber_bubble, label="BubbleSort")
plt.ticklabel_format(style='plain')
plt.xticks([40000,80000,160000,320000,640000,1280000,2560000])
plt.ylabel("Tempo de execução (ms)")
plt.xlabel("Quantidade de pontos")
plt.title("Média LSTUBER de execução dos métodos de sorteamento")
plt.legend()
plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='center')
plt.gcf().set_size_inches(11, 5)
plt.show()

# %%
#Dados LAPTOP-LSTUBER

media_lstuber2_selection = []
media_lstuber2_insertion = []
media_lstuber2_bubble = []
dados_lstuber = dados.loc[dados["pc"] == "LAPTOP-LSTUBER", :]

for tipo in tipos:
    for qntd in quantidade:
        dados_selection = dados_lstuber.loc[dados_lstuber["tipo"] == tipo, :]
        dados_selection = dados_selection.loc[dados_selection["tamanho"] == qntd, :]
        if (tipo=="selectionSort"):
            media_lstuber2_selection.append(dados_selection["tempo"].mean())
        elif tipo == "insertionSort":
            media_lstuber2_insertion.append(dados_selection["tempo"].mean())
        else:
            media_lstuber2_bubble.append(dados_selection["tempo"].mean())

plt.plot(quantidade,media_lstuber2_selection, label="SelectionSort")
plt.plot(quantidade,media_lstuber2_insertion, label="InsertionSort")
plt.plot(quantidade,media_lstuber2_bubble, label="BubbleSort")
plt.ticklabel_format(style='plain')
plt.xticks([40000,80000,160000,320000,640000,1280000,2560000])
plt.ylabel("Tempo de execução (ms)")
plt.xlabel("Quantidade de pontos")
plt.title("Média LSTUBER2 de execução dos métodos de sorteamento")
plt.legend()
plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='center')
plt.gcf().set_size_inches(11, 5)
plt.show()

# %%
#Dados MSI

media_msi_selection = []
media_msi_insertion = []
media_msi_bubble = []
dados_msi = dados.loc[dados["pc"] == "MSI", :]

for tipo in tipos:
    for qntd in quantidade:
        dados_selection = dados_msi.loc[dados_msi["tipo"] == tipo, :]
        dados_selection = dados_selection.loc[dados_selection["tamanho"] == qntd, :]
        if (tipo=="selectionSort"):
            media_msi_selection.append(dados_selection["tempo"].mean())
        elif tipo == "insertionSort":
            media_msi_insertion.append(dados_selection["tempo"].mean())
        else:
            media_msi_bubble.append(dados_selection["tempo"].mean())

plt.plot(quantidade,media_msi_selection, label="SelectionSort")
plt.plot(quantidade,media_msi_insertion, label="InsertionSort")
plt.plot(quantidade,media_msi_bubble, label="BubbleSort")
plt.ticklabel_format(style='plain')
plt.xticks([40000,80000,160000,320000,640000,1280000,2560000])
plt.ylabel("Tempo de execução (ms)")
plt.xlabel("Quantidade de pontos")
plt.title("Média MSI de execução dos métodos de sorteamento")
plt.legend()
plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='center')
plt.gcf().set_size_inches(11, 5)
plt.show()

# %%
#Dados Carlos-PC

media_carlos_selection = []
media_carlos_insertion = []
media_carlos_bubble = []
dados_carlos = dados.loc[dados["pc"] == "Carlos-PC", :]

for tipo in tipos:
    for qntd in quantidade:
        dados_selection = dados_carlos.loc[dados_carlos["tipo"] == tipo, :]
        dados_selection = dados_selection.loc[dados_selection["tamanho"] == qntd, :]
        if (tipo=="selectionSort"):
            media_carlos_selection.append(dados_selection["tempo"].mean())
        elif tipo == "insertionSort":
            media_carlos_insertion.append(dados_selection["tempo"].mean())
        else:
            media_carlos_bubble.append(dados_selection["tempo"].mean())

            
plt.plot(quantidade,media_carlos_selection, label="SelectionSort")
plt.plot(quantidade,media_carlos_insertion, label="InsertionSort")
plt.plot(quantidade,media_carlos_bubble, label="BubbleSort")
plt.ticklabel_format(style='plain')
plt.xticks([40000,80000,160000,320000,640000,1280000,2560000])
plt.ylabel("Tempo de execução (ms)")
plt.xlabel("Quantidade de pontos")
plt.title("Média Carlos de execução dos métodos de sorteamento")
plt.legend()
plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='center')
plt.gcf().set_size_inches(11, 5)
plt.show()

# %%
#Dados LAPTOP-NEWTON

media_newton_selection = []
media_newton_insertion = []
media_newton_bubble = []
dados_newton = dados.loc[dados["pc"] == "LAPTOP-NEWTON", :]

for tipo in tipos:
    for qntd in quantidade:
        dados_selection = dados_newton.loc[dados_newton["tipo"] == tipo, :]
        dados_selection = dados_selection.loc[dados_selection["tamanho"] == qntd, :]
        if (tipo=="selectionSort"):
            media_newton_selection.append(dados_selection["tempo"].mean())
        elif tipo == "insertionSort":
            media_newton_insertion.append(dados_selection["tempo"].mean())
        else:
            media_newton_bubble.append(dados_selection["tempo"].mean())

plt.plot(quantidade,media_newton_selection, label="SelectionSort")
plt.plot(quantidade,media_newton_insertion, label="InsertionSort")
plt.plot(quantidade,media_newton_bubble, label="BubbleSort")
plt.ticklabel_format(style='plain')
plt.xticks([40000,80000,160000,320000,640000,1280000,2560000])
plt.ylabel("Tempo de execução (ms)")
plt.xlabel("Quantidade de pontos")
plt.title("Média Newton de execução dos métodos de sorteamento")
plt.legend()
plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='center')
plt.gcf().set_size_inches(11, 5)
plt.show()

# %%
#Dados Othavio

media_othavio_selection = []
media_othavio_insertion = []
media_othavio_bubble = []
dados_othavio = dados.loc[dados["pc"] == "Othavio", :]

for tipo in tipos:
    for qntd in quantidade:
        dados_selection = dados_othavio.loc[dados_othavio["tipo"] == tipo, :]
        dados_selection = dados_selection.loc[dados_selection["tamanho"] == qntd, :]
        if (tipo=="selectionSort"):
            media_othavio_selection.append(dados_selection["tempo"].mean())
        elif tipo == "insertionSort":
            media_othavio_insertion.append(dados_selection["tempo"].mean())
        else:
            media_othavio_bubble.append(dados_selection["tempo"].mean())
        
plt.plot(quantidade,media_othavio_selection, label="SelectionSort")
plt.plot(quantidade,media_othavio_insertion, label="InsertionSort")
plt.plot(quantidade,media_othavio_bubble, label="BubbleSort")
plt.ticklabel_format(style='plain')
plt.xticks([40000,80000,160000,320000,640000,1280000,2560000])
plt.ylabel("Tempo de execução (ms)")
plt.xlabel("Quantidade de pontos")
plt.title("Média Othavio de execução dos métodos de sorteamento")
plt.legend()
plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='center')
plt.gcf().set_size_inches(11, 5)
plt.show()

# %%
#Dados gerais

dados_gerais_selection = []
dados_gerais_insertion = []
dados_gerais_bubble = []
i = 0
while i < len(quantidade):
    media_valores_selection = (media_lstuber_selection[i]+media_lstuber2_selection[i]+media_msi_selection[i]+media_carlos_selection[i]+media_newton_selection[i]+media_othavio_selection[i])/6
    media_valores_insertion = (media_lstuber_insertion[i]+media_lstuber2_insertion[i]+media_msi_insertion[i]+media_carlos_insertion[i]+media_newton_insertion[i]+media_othavio_insertion[i])/6
    media_valores_bubble = (media_lstuber_bubble[i]+media_lstuber2_bubble[i]+media_msi_bubble[i]+media_carlos_bubble[i]+media_newton_bubble[i]+media_othavio_bubble[i])/6
    dados_gerais_selection.append(media_valores_selection)
    dados_gerais_insertion.append(media_valores_insertion)
    dados_gerais_bubble.append(media_valores_bubble)
    i += 1

plt.plot(quantidade,dados_gerais_selection, label="SelectionSort")
plt.plot(quantidade,dados_gerais_insertion, label="InsertionSort")
plt.plot(quantidade,dados_gerais_bubble, label="BubbleSort")
plt.ticklabel_format(style='plain')
plt.xticks([40000,80000,160000,320000,640000,1280000,2560000])
plt.ylabel("Tempo de execução (ms)")
plt.xlabel("Quantidade de pontos")
plt.title("Média geral do tempo de execução dos métodos de sorteamento")
plt.legend()
plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='center')
plt.gcf().set_size_inches(11, 5)
plt.show()
